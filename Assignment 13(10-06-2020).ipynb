# %% [markdown]
# ### Import the package

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/upvotes.csv")
df
# Out:
#             ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177   8067.0     60.0
# 3        96996   a       264.0      3.0    168793  27064.0      9.0
# 4       131465   c      4271.0      4.0    112223  13986.0     83.0
# ...        ...  ..         ...      ...       ...      ...      ...
# 330040  339800   c        36.0      2.0     84919   1063.0      0.0
# 330041  253800   c      1649.0      2.0     76730  23319.0     73.0
# 330042  210756   c      6178.0      2.0     91701   2453.0     15.0
# 330043   56089   j        89.0      2.0     80245   2107.0      3.0
# 330044  300553   j      2001.0      4.0    154692   2554.0     37.0
#
# [330045 rows x 7 columns]

# %%
import seaborn as sns 
votes=sns.implot("Tag","UPvotes",data=df)
votes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-82fb8bc24d12> in <module>
#       1 import seaborn as sns
# ----> 2 votes=sns.implot("Tag","UPvotes",data=df)
#       3 votes
#
# AttributeError: module 'seaborn' has no attribute 'implot'

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Capture the original matplotlib rcParams
#
# PACKAGE CONTENTS
#     algorithms
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     conftest
#     distributions
#     external (package)
#     matrix
#     miscplot
#     palettes
#     rcmod
#     regression
#     relational
#     tests (package)
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.10.0
#
# FILE
#     c:\users\karthik\anaconda3\lib\site-packages\seaborn\__init__.py
